# %% [markdown]
# # Итоговый проект. Улицы. Объекты культурного наследия.

# %%
# DONE todo собрать установку всех необходимых модулей в одном месте
# !pip install folium -U
# !pip install geopandas mapclassify
# !pip install osmnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.7/dist-packages (2.4.3)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.4)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.22)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.2.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.9.24)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from mapclassify) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from mapclassify) (1.7.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from mapclassify) (2.6.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->mapclassify) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->mapclassify) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: osmnx in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Requirement already satisfied: Shapely<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.8.4)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.3.5)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.28.1)
# Requirement already satisfied: Rtree>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.0.1)
# Requirement already satisfied: pyproj>=3.2 in /usr/local/lib/python3.7/dist-packages (from osmnx) (3.2.1)
# Requirement already satisfied: geopandas>=0.10 in /usr/local/lib/python3.7/dist-packages (from osmnx) (0.10.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.21.6)
# Requirement already satisfied: networkx>=2.6 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.6.3)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.7/dist-packages (from osmnx) (3.5.3)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.10->osmnx) (1.8.22)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (0.7.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (22.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (2022.9.24)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (1.1.1)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (2.5.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (57.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.4->osmnx) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.3->osmnx) (2022.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (2.10)

# %%
# DONE todo собрать импорты всех модулей в одном месте
import pandas as pd
import geopandas as gpd
import osmnx as ox

# %%
# DONE todo указать через константу, чтобы везде была одна и та же подложка карт. Сейчас в работе название захардкожено 
TILES = "CartoDB positron"

# DONE todo собрать все константы в одном месте
# DONE todo указать любой район Санкт-Петербург из OSM https://wiki.openstreetmap.org/wiki/RU:%D0%A1%D0%B0%D0%BD%D0%BA%D1%82-%D0%9F%D0%B5%D1%82%D0%B5%D1%80%D0%B1%D1%83%D1%80%D0%B3/%D0%A0%D0%B0%D0%B9%D0%BE%D0%BD%D1%8B
TERRITORY_NAME = 'Василеостровский район, Санкт-Петербург'  # например, 'Адмиралтейский район, Санкт-Петербург'
STREETS_FILE_URL = "https://drive.google.com/file/d/1bUT1E-QSbG1vpSNM2dOG2-LEVXSrPdo3/view?usp=sharing"
# DONE todo указать ссылку на файл из вашего github репозитория, которая начинается с https://raw.githubusercontent.com/
KGIOP_FILE_URL = "https://raw.githubusercontent.com/pashkalini/PythonUrbanFinalTask/main/kgiop_objects.geojson"
STREET_BUFFER = 100

# %%
def get_google_drive_download_url(url: str) -> str:
    """
    Функция возвращает ссылку для скачивания с google drive.
     Например: "https://drive.google.com/file/d/1MWGOuqV76e0ubQOg8Ke0KTU3yGpkprHp/view?usp=sharing" ->
     "https://drive.google.com/uc?export=download&id=1MWGOuqV76e0ubQOg8Ke0KTU3yGpkprHp"
    """
    drive_id = url.split("/")[5]
    return f"https://drive.google.com/uc?export=download&id={drive_id}"

# %% [markdown]
# ## Территория

# %% [markdown]
# ### Загрузка территории из OSM (Extract)

# %%
territory = ox.geocode_to_gdf(TERRITORY_NAME)  # подгружаем с OSM и получаем GeoDataFrame
territory.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3facf164970de7ea9f41656f09ae2ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3facf164970de7ea9f41656f09ae2ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d3facf164970de7ea9f41656f09ae2ea = L.map(
#                 &quot;map_d3facf164970de7ea9f41656f09ae2ea&quot;,
#                 {
#                     center: [59.940817949999996, 30.24736685],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d3facf164970de7ea9f41656f09ae2ea);
#
#
#
#
#
#             var tile_layer_435020c95c1857f6e45fcdaa2eab2f84 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d3facf164970de7ea9f41656f09ae2ea);
#
#
#             map_d3facf164970de7ea9f41656f09ae2ea.fitBounds(
#                 [[59.9172603, 30.1778731], [59.9643756, 30.3168606]],
#                 {}
#             );
#
#
#         function geo_json_b63b48196b858118ed6df2dd27a05490_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b63b48196b858118ed6df2dd27a05490_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b63b48196b858118ed6df2dd27a05490_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b63b48196b858118ed6df2dd27a05490_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b63b48196b858118ed6df2dd27a05490_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b63b48196b858118ed6df2dd27a05490.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b63b48196b858118ed6df2dd27a05490_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b63b48196b858118ed6df2dd27a05490 = L.geoJson(null, {
#                 onEachFeature: geo_json_b63b48196b858118ed6df2dd27a05490_onEachFeature,
#
#                 style: geo_json_b63b48196b858118ed6df2dd27a05490_styler,
#                 pointToLayer: geo_json_b63b48196b858118ed6df2dd27a05490_pointToLayer
#         });
#
#         function geo_json_b63b48196b858118ed6df2dd27a05490_add (data) {
#             geo_json_b63b48196b858118ed6df2dd27a05490
#                 .addData(data)
#                 .addTo(map_d3facf164970de7ea9f41656f09ae2ea);
#         }
#             geo_json_b63b48196b858118ed6df2dd27a05490_add({&quot;bbox&quot;: [30.1778731, 59.9172603, 30.3168606, 59.9643756], &quot;features&quot;: [{&quot;bbox&quot;: [30.1778731, 59.9172603, 30.3168606, 59.9643756], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.1778731, 59.9443695], [30.1778995, 59.9440329], [30.1782257, 59.9437134], [30.180871, 59.9430763], [30.1827454, 59.941069], [30.1901627, 59.9331231], [30.1905995, 59.9327563], [30.1910845, 59.9323489], [30.1923895, 59.9316415], [30.1939339, 59.9310989], [30.2014911, 59.9290013], [30.2026574, 59.9287305], [30.2039643, 59.9285382], [30.2055294, 59.928443], [30.209122, 59.9283845], [30.2119478, 59.9283383], [30.214277, 59.9283003], [30.2171279, 59.9282

# %% [markdown]
# ### Обработка данных с территорией (Transform)

# %%
territory
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((30.17787 59.94437, 30.17790 59.94403...   59.964376    59.91726
#
#    bbox_east  bbox_west   place_id  osm_type   osm_id        lat        lon  \
# 0  30.316861  30.177873  298216825  relation  1114252  59.939275  30.243876
#
#                                         display_name     class  \
# 0  Василеостровский район, Saint Petersburg, Nort...  boundary
#
#              type  importance
# 0  administrative    0.600226

# %% [markdown]
# Добавим новый столбец с "Название территории"

# %%
# DONE todo добавить столбец Название территории и удалить все остальные (кроме столбца geometry)
territory['Название территории'] = TERRITORY_NAME

# %% [markdown]
# Оставим только столбец *geometry* и новый с названием территории

# %%
#territory = territory[['Название территории', 'geometry']]
territory = territory.loc[:, ('Название территории', 'geometry')]
territory
# Out:
#                        Название территории  \
# 0  Василеостровский район, Санкт-Петербург
#
#                                             geometry
# 0  POLYGON ((30.17787 59.94437, 30.17790 59.94403...

# %% [markdown]
# ## Улицы

# %% [markdown]
# ### Загрузка файла с улицами из google disk (Extract)

# %% [markdown]
#  Отфильтруем улицы по маске геометрии территории

# %%
url = get_google_drive_download_url(STREETS_FILE_URL)
# DONE todo отфильтровать улицы по маске геометрии территории полученной ранее
gdf_streets = gpd.read_file(url, mask=territory.geometry)
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4454390  {'foot': 'no', 'highway': 'unclassified', 'lan...
# 1     way    4454543     {'highway': 'service', 'living_street': 'yes'}
# 2     way    4454721     {'highway': 'service', 'living_street': 'yes'}
# 3     way    4454767     {'highway': 'service', 'living_street': 'yes'}
# 4     way    4455074  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# ...   ...        ...                                                ...
# 5494  way  983003449  {'foot': 'no', 'highway': 'residential', 'lane...
# 5495  way  983003450  {'foot': 'no', 'highway': 'residential', 'lane...
# 5496  way  983133694                             {'highway': 'service'}
# 5497  way  983133697  {'highway': 'service', 'layer': '-1', 'tunnel'...
# 5498  way  983133698                             {'highway': 'service'}
#
#                                                geometry
# 0     LINESTRING (3366312.890 8383418.064, 3366318.9...
# 1     LINESTRING (3364065.060 8389870.685, 3364042.8...
# 2     LINESTRING (3366216.843 8386214.551, 3366217.3...
# 3     LINESTRING (3363246.227 8390001.823, 3363259.4...
# 4     LINESTRING (3364793.702 8386752.080, 3364743.2...
# ...                                                 ...
# 5494  LINESTRING (3365411.091 8388516.042, 3365410.5...
# 5495  LINESTRING (3365780.426 8389603.970, 3365742.5...
# 5496  LINESTRING (3368553.384 8387054.742, 3368548.4...
# 5497  LINESTRING (3368611.225 8387181.673, 3368580.9...
# 5498  LINESTRING (3368634.469 8387195.098, 3368614.2...
#
# [5499 rows x 4 columns]

# %% [markdown]
# ### Обработка данных с улицами (Transform)

# %% [markdown]
# Посмотрим все данные по улицам района

# %%
tags = pd.json_normalize(gdf_streets["tags"])
tags
# Out:
#      foot       highway lanes  lit  maxspeed              name  \
# 0      no  unclassified     2  yes  RU:urban  Кожевенная линия
# 1     NaN       service   NaN  NaN       NaN               NaN
# 2     NaN       service   NaN  NaN       NaN               NaN
# 3     NaN       service   NaN  NaN       NaN               NaN
# 4      no     secondary     3  yes  RU:urban    улица Нахимова
# ...   ...           ...   ...  ...       ...               ...
# 5494   no   residential     1  yes  RU:urban               NaN
# 5495   no   residential     1  yes  RU:urban               NaN
# 5496  NaN       service   NaN  NaN       NaN               NaN
# 5497  NaN       service   NaN  NaN       NaN               NaN
# 5498  NaN       service   NaN  NaN       NaN               NaN
#
#                 name:en           name:ru  surface trolley_wire  ...  \
# 0     Kozhevennaya Line  Кожевенная линия  asphalt          yes  ...
# 1                   NaN               NaN      NaN          NaN  ...
# 2                   NaN               NaN      NaN          NaN  ...
# 3                   NaN               NaN      NaN          NaN  ...
# 4       Nahimova Street    улица Нахимова  asphalt          yes  ...
# ...                 ...               ...      ...          ...  ...
# 5494                NaN               NaN  asphalt          NaN  ...
# 5495                NaN               NaN  asphalt          NaN  ...
# 5496                NaN               NaN      NaN          NaN  ...
# 5497                NaN               NaN      NaN          NaN  ...
# 5498                NaN               NaN      NaN          NaN  ...
#
#      cycleway:right maxweight surface:note fixme proposed motor_vehicle  \
# 0               NaN       NaN          NaN   NaN      NaN           NaN
# 1               NaN       NaN          NaN   NaN      NaN           NaN
# 2               NaN       NaN          NaN   NaN      NaN           NaN
# 3               NaN       NaN          NaN   NaN      NaN           NaN
# 4               NaN       NaN          NaN   NaN      NaN           NaN
# ...             ...       ...          ...   ...      ...           ...
# 5494            NaN       NaN          NaN   NaN      NaN           NaN
# 5495            NaN       NaN          NaN   NaN      NaN           NaN
# 5496            NaN       NaN          NaN   NaN      NaN           NaN
# 5497            NaN       NaN          NaN   NaN      NaN           NaN
# 5498            NaN       NaN          NaN   NaN      NaN           NaN
#
#      turn:backward turn:forward lane_markings parking:condition:right
# 0              NaN          NaN           NaN                     NaN
# 1              NaN          NaN           NaN                     NaN
# 2              NaN          NaN           NaN                     NaN
# 3              NaN          NaN           NaN                     NaN
# 4              NaN          NaN           NaN                     NaN
# ...            ...          ...           ...                     ...
# 5494           NaN          NaN           NaN                     NaN
# 5495           NaN          NaN           NaN                     NaN
# 5496           NaN          NaN           NaN                     NaN
# 5497           NaN          NaN           NaN                     NaN
# 5498           NaN          NaN           NaN                     NaN
#
# [5499 rows x 81 columns]

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5499 entries, 0 to 5498
# Data columns (total 81 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   foot                         791 non-null    object
#  1   highway                      5499 non-null   object
#  2   lanes                        900 non-null    object
#  3   lit                          869 non-null    object
#  4   maxspeed                     887 non-null    object
#  5   name                         826 non-null    object
#  6   name:en                      642 non-null    object
#  7   name:ru                      642 non-null    object
#  8   surface                      2103 non-null   object
#  9   trolley_wire                 206 non-null    object
#  10  living_street                1536 non-null   object
#  11  oneway                       761 non-null    object
#  12  lanes:forward                10 non-null     object
#  13  postal_code                  35 non-null     object
#  14  sidewalk                     36 non-null     object
#  15  addr:postcode                79 non-null     object
#  16  wikidata                     113 non-null    object
#  17  wikipedia                    113 non-null    object
#  18  alt_name                     6 non-null      object
#  19  side_road                    59 non-null     object
#  20  check_date                   28 non-null     object
#  21  smoothness                   43 non-null     object
#  22  turn:lanes                   90 non-null     object
#  23  source                       94 non-null     object
#  24  vehicle                      61 non-null     object
#  25  service                      253 non-null    object
#  26  noname                       7 non-null      object
#  27  note                         12 non-null     object
#  28  layer                        90 non-null     object
#  29  lanes:backward               7 non-null      object
#  30  turn:lanes:backward          4 non-null      object
#  31  narrow                       2 non-null      object
#  32  covered                      365 non-null    object
#  33  tunnel                       617 non-null    object
#  34  access                       405 non-null    object
#  35  old_name                     10 non-null     object
#  36  turn:lanes:forward           5 non-null      object
#  37  maxheight                    200 non-null    object
#  38  bridge                       63 non-null     object
#  39  name:de                      8 non-null      object
#  40  placement                    1 non-null      object
#  41  bridge:movable               8 non-null      object
#  42  name:fr                      4 non-null      object
#  43  old_name:de                  2 non-null      object
#  44  description                  6 non-null      object
#  45  source:maxspeed              23 non-null     object
#  46  toll                         23 non-null     object
#  47  cutting                      6 non-null      object
#  48  surface:grade                4 non-null      object
#  49  step_count                   1 non-null      object
#  50  width                        1 non-null      object
#  51  embankment                   4 non-null      object
#  52  turn                         3 non-null      object
#  53  destination                  9 non-null      object
#  54  hgv                          5 non-null      object
#  55  parking:side:left            3 non-null      object
#  56  construction                 12 non-null     object
#  57  footway                      5 non-null      object
#  58  maxspeed:type                1 non-null      object
#  59  source:name                  3 non-null      object
#  60  incline                      43 non-null     object
#  61  check_date:surface           3 non-null      object
#  62  maxweight:signed             9 non-null      object
#  63  was:oneway                   1 non-null      object
#  64  parking:lane:right           6 non-null      object
#  65  parking:lane:right:parallel  2 non-null      object
#  66  parking:lane:left            5 non-null      object
#  67  parking:lane:both            4 non-null      object
#  68  name:zh                      1 non-null      object
#  69  maxaxleload                  2 non-null      object
#  70  bicycle                      14 non-null     object
#  71  cycleway:right               14 non-null     object
#  72  maxweight                    1 non-null      object
#  73  surface:note                 1 non-null      object
#  74  fixme                        2 non-null      object
#  75  proposed                     2 non-null      object
#  76  motor_vehicle                4 non-null      object
#  77  turn:backward                3 non-null      object
#  78  turn:forward                 2 non-null      object
#  79  lane_markings                1 non-null      object
#  80  parking:condition:right      1 non-null      object
# dtypes: object(81)
# memory usage: 3.4+ MB

# %%
extract_tags = [
    'name'  # DONE todo указать в списке строку "name"
]

gdf_streets = gdf_streets.join(tags[extract_tags])
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4454390  {'foot': 'no', 'highway': 'unclassified', 'lan...
# 1     way    4454543     {'highway': 'service', 'living_street': 'yes'}
# 2     way    4454721     {'highway': 'service', 'living_street': 'yes'}
# 3     way    4454767     {'highway': 'service', 'living_street': 'yes'}
# 4     way    4455074  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# ...   ...        ...                                                ...
# 5494  way  983003449  {'foot': 'no', 'highway': 'residential', 'lane...
# 5495  way  983003450  {'foot': 'no', 'highway': 'residential', 'lane...
# 5496  way  983133694                             {'highway': 'service'}
# 5497  way  983133697  {'highway': 'service', 'layer': '-1', 'tunnel'...
# 5498  way  983133698                             {'highway': 'service'}
#
#                                                geometry              name
# 0     LINESTRING (3366312.890 8383418.064, 3366318.9...  Кожевенная линия
# 1     LINESTRING (3364065.060 8389870.685, 3364042.8...               NaN
# 2     LINESTRING (3366216.843 8386214.551, 3366217.3...               NaN
# 3     LINESTRING (3363246.227 8390001.823, 3363259.4...               NaN
# 4     LINESTRING (3364793.702 8386752.080, 3364743.2...    улица Нахимова
# ...                                                 ...               ...
# 5494  LINESTRING (3365411.091 8388516.042, 3365410.5...               NaN
# 5495  LINESTRING (3365780.426 8389603.970, 3365742.5...               NaN
# 5496  LINESTRING (3368553.384 8387054.742, 3368548.4...               NaN
# 5497  LINESTRING (3368611.225 8387181.673, 3368580.9...               NaN
# 5498  LINESTRING (3368634.469 8387195.098, 3368614.2...               NaN
#
# [5499 rows x 5 columns]

# %% [markdown]
# Удалим строки с отстутсвующими названиями улиц

# %%
gdf_streets.dropna(
    how="all",  # удалить если отсутствуют значения во всех указанных столбцах
    subset=["name"],  # столбцы, в которых надо искать пропуски
    inplace=True
)
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4454390  {'foot': 'no', 'highway': 'unclassified', 'lan...
# 4     way    4455074  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 6     way    4455758  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 7     way    4456100  {'highway': 'residential', 'lanes': '1', 'lit'...
# 10    way    4456704  {'foot': 'no', 'highway': 'residential', 'lane...
# ...   ...        ...                                                ...
# 5412  way  946864884  {'highway': 'residential', 'lanes': '2', 'lit'...
# 5415  way  951667505  {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# 5416  way  951667506  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 5456  way  957802292  {'bicycle': 'designated', 'check_date': '2017-...
# 5461  way  964399430  {'construction': 'residential', 'highway': 'co...
#
#                                                geometry  \
# 0     LINESTRING (3366312.890 8383418.064, 3366318.9...
# 4     LINESTRING (3364793.702 8386752.080, 3364743.2...
# 6     LINESTRING (3368203.462 8387924.925, 3368216.1...
# 7     LINESTRING (3368114.551 8385036.156, 3368124.6...
# 10    LINESTRING (3367355.174 8388720.917, 3367360.5...
# ...                                                 ...
# 5412  LINESTRING (3362469.039 8385708.171, 3362340.7...
# 5415  LINESTRING (3369235.249 8388117.669, 3369199.1...
# 5416  LINESTRING (3369481.065 8388327.601, 3369496.5...
# 5456  LINESTRING (3368901.691 8384926.614, 3368882.4...
# 5461  LINESTRING (3361028.631 8386847.602, 3361158.5...
#
#                           name
# 0             Кожевенная линия
# 4               улица Нахимова
# 6           16-17-я линии В.О.
# 7             Клубный переулок
# 10        переулок Декабристов
# ...                        ...
# 5412  бульвар Александра Грина
# 5415  набережная реки Смоленки
# 5416            9-я линия В.О.
# 5456     Большой проспект В.О.
# 5461     проспект Крузенштерна
#
# [826 rows x 5 columns]

# %% [markdown]
# Проверим наличие дубликатов

# %%
# DONE todo проверить наличие дубликатов по полям "id", "geometry", "name"
gdf_streets.duplicated(subset=["id", "geometry", "name"]).value_counts()
# Out:
# False    826
# dtype: int64

# %% [markdown]
# Посмотрим, являются ли названия улиц уникальными

# %%
gdf_streets["name"].is_unique
# Out:
# False

# %% [markdown]
# При помощи метода *dissolve* группируем геометрии по столбцу *name* и объединяем геометрии с одинаковыми названиями

# %%
gdf_streets = gdf_streets.dissolve(by="name")  # DONE todo сгруппировать и объединить геометрии с одинаковыми названиями
gdf_streets
# Out:
#                                                              geometry type  \
# name
# 1-я линия В.О.      MULTILINESTRING ((3371228.480 8388213.098, 337...  way
# 10-11-я линии В.О.  MULTILINESTRING ((3369235.249 8388117.669, 336...  way
# 12-13-я линии В.О.  MULTILINESTRING ((3370596.664 8385143.832, 337...  way
# 14-15-я линии В.О.  LINESTRING (3369473.640 8386432.496, 3369476.8...  way
# 14-я линия В.О.     LINESTRING (3369473.640 8386432.496, 3369470.2...  way
# ...                                                               ...  ...
# улица Нахимова      MULTILINESTRING ((3364793.702 8386752.080, 336...  way
# улица Одоевского    MULTILINESTRING ((3368096.740 8388961.412, 336...  way
# улица Репина        MULTILINESTRING ((3371298.233 8387498.912, 337...  way
# улица Челюскина     LINESTRING (3361436.751 8386728.833, 3361263.5...  way
# улица Шевченко      MULTILINESTRING ((3367088.419 8383856.438, 336...  way
#
#                            id  \
# name
# 1-я линия В.О.      128224708
# 10-11-я линии В.О.   31364918
# 12-13-я линии В.О.  240799870
# 14-15-я линии В.О.  173075244
# 14-я линия В.О.      31389152
# ...                       ...
# улица Нахимова        4455074
# улица Одоевского      4458561
# улица Репина         25091782
# улица Челюскина     883287660
# улица Шевченко       31378667
#
#                                                                  tags
# name
# 1-я линия В.О.      {'foot': 'no', 'highway': 'primary', 'lanes': ...
# 10-11-я линии В.О.  {'foot': 'no', 'highway': 'residential', 'lane...
# 12-13-я линии В.О.  {'foot': 'no', 'highway': 'residential', 'lane...
# 14-15-я линии В.О.  {'foot': 'no', 'highway': 'residential', 'lane...
# 14-я линия В.О.     {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# ...                                                               ...
# улица Нахимова      {'foot': 'no', 'highway': 'secondary', 'lanes'...
# улица Одоевского    {'foot': 'no', 'highway': 'residential', 'lane...
# улица Репина        {'foot': 'yes', 'highway': 'residential', 'lan...
# улица Челюскина     {'highway': 'residential', 'name': 'улица Челю...
# улица Шевченко      {'foot': 'no', 'highway': 'tertiary', 'lanes':...
#
# [122 rows x 4 columns]

# %% [markdown]
# Меняем название первого столбца (индекса)  с *name* на *Название улицы*

# %%
gdf_streets.index.rename("Название улицы", inplace=True)
gdf_streets.head()
# Out:
#                                                              geometry type  \
# Название улицы
# 1-я линия В.О.      MULTILINESTRING ((3371228.480 8388213.098, 337...  way
# 10-11-я линии В.О.  MULTILINESTRING ((3369235.249 8388117.669, 336...  way
# 12-13-я линии В.О.  MULTILINESTRING ((3370596.664 8385143.832, 337...  way
# 14-15-я линии В.О.  LINESTRING (3369473.640 8386432.496, 3369476.8...  way
# 14-я линия В.О.     LINESTRING (3369473.640 8386432.496, 3369470.2...  way
#
#                            id  \
# Название улицы
# 1-я линия В.О.      128224708
# 10-11-я линии В.О.   31364918
# 12-13-я линии В.О.  240799870
# 14-15-я линии В.О.  173075244
# 14-я линия В.О.      31389152
#
#                                                                  tags
# Название улицы
# 1-я линия В.О.      {'foot': 'no', 'highway': 'primary', 'lanes': ...
# 10-11-я линии В.О.  {'foot': 'no', 'highway': 'residential', 'lane...
# 12-13-я линии В.О.  {'foot': 'no', 'highway': 'residential', 'lane...
# 14-15-я линии В.О.  {'foot': 'no', 'highway': 'residential', 'lane...
# 14-я линия В.О.     {'foot': 'no', 'highway': 'tertiary', 'lanes':...

# %% [markdown]
# Удалим столбцы *id*, *type* и *tags*

# %%
# todo удалить столбцы "id", "type" и "tags"
drop_columns = [
    'id',
    'type',
    'tags'
]
gdf_streets.drop(columns=drop_columns, inplace=True)
gdf_streets.head()
# Out:
#                                                              geometry
# Название улицы
# 1-я линия В.О.      MULTILINESTRING ((3371228.480 8388213.098, 337...
# 10-11-я линии В.О.  MULTILINESTRING ((3369235.249 8388117.669, 336...
# 12-13-я линии В.О.  MULTILINESTRING ((3370596.664 8385143.832, 337...
# 14-15-я линии В.О.  LINESTRING (3369473.640 8386432.496, 3369476.8...
# 14-я линия В.О.     LINESTRING (3369473.640 8386432.496, 3369470.2...

# %% [markdown]
# Отобразим полученную геометрию (улицы района)

# %%
gdf_streets.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e7402ef359ccece33d49a3f93bfd3ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e7402ef359ccece33d49a3f93bfd3ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0e7402ef359ccece33d49a3f93bfd3ed = L.map(
#                 &quot;map_0e7402ef359ccece33d49a3f93bfd3ed&quot;,
#                 {
#                     center: [59.94541845, 30.251080950000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0e7402ef359ccece33d49a3f93bfd3ed);
#
#
#
#
#
#             var tile_layer_494082ea31fc03afab0730a90ac173be = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e7402ef359ccece33d49a3f93bfd3ed);
#
#
#             map_0e7402ef359ccece33d49a3f93bfd3ed.fitBounds(
#                 [[59.921740099999994, 30.192633900000004], [59.9690968, 30.309527999999997]],
#                 {}
#             );
#
#
#         function geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5e92a0a60b8eb163d382b4dd247e9bcd.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5e92a0a60b8eb163d382b4dd247e9bcd = L.geoJson(null, {
#                 onEachFeature: geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_onEachFeature,
#
#                 style: geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_styler,
#                 pointToLayer: geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_pointToLayer
#         });
#
#         function geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_add (data) {
#             geo_json_5e92a0a60b8eb163d382b4dd247e9bcd
#                 .addData(data)
#                 .addTo(map_0e7402ef359ccece33d49a3f93bfd3ed);
#         }
#             geo_json_5e92a0a60b8eb163d382b4dd247e9bcd_add({&quot;bbox&quot;: [30.192633900000004, 59.921740099999994, 30.309527999999997, 59.9690968], &quot;features&quot;: [{&quot;bbox&quot;: [30.283680600000004, 59.9382375, 30.2944292, 59.948195], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.284260700000004, 59.948195], [30.2841502, 59.9481108]], [[30.283897600000003, 59.9479116], [30.28379, 59.94779569999999]], [[30.28379, 59.94779569999999], [30.2837273, 59.9476968], [30.283699900000002, 59.9476142], [30.283680600000004, 59.947559799999986], [30.2836868, 59.94750099999999], [30.2837327, 59.947378400000005], [30.283766800000002, 59.9473414], [30.2838237, 59.94727950000001], [30.283

# %% [markdown]
# ## Объекты культурного наследия

# %% [markdown]
# ### Загрузка объектов культурного наследия

# %%
gdf_kgiop_objects = gpd.read_file(KGIOP_FILE_URL, mask=territory)
gdf_kgiop_objects
# Out:
#        id                                      ensemble_name  \
# 0    1260                                                  —
# 1    1021               Дом И.В. Голубина (И.И. Зайцевского)
# 2    1015                                                  —
# 3    1016                                                  —
# 4    1017                                                  —
# ..    ...                                                ...
# 777  9441  Комплекс зданий Французского благотворительног...
# 778  9442  Комплекс зданий Французского благотворительног...
# 779  9517                                                  —
# 780  9605                                  Два жилых флигеля
# 781  9606                                  Два жилых флигеля
#
#                                            object_name  \
# 0                                    Дом А.Р. Гешвенда
# 1                                              Флигель
# 2                   Дом Г.И. Головкина (А.Н. Чичагова)
# 3                    Дом Леонтьева М.И. (Шуберта Ф.Ф.)
# 4                         Дом А. Сверчкова (Кушелевой)
# ..                                                 ...
# 777                                             Ограда
# 778                                                Сад
# 779  Главное здание Государственного оптического ин...
# 780                                      Жилой флигель
# 781                                      Жилой флигель
#
#              occurrence_time                      object_location  \
# 0                  1880-1881                   9-я линия В.О., 32
# 1           нач. 19 в.; 1834                       Репина ул., 17
# 2      1720-е - 1730-е; 1878    1-я линия В.О., 10; Репина ул., 9
# 3       1722-1741, 1807-1809                   1-я линия В.О., 12
# 4    1730-1740-е; 1815; 1863           1-я линия В.О., 14, лит. А
# ..                       ...                                  ...
# 777                     1905               14-я линия В.О., 57-61
# 778     кон. 19 - нач. 20 в.               14-я линия В.О., 57-61
# 779                1947-1956  Кадетская линия, 5, корп. 2, лит. В
# 780         кон. 18 в.; 1848           4-я линия В.О., 39, лит. Б
# 781         кон. 18 в.; 1848           4-я линия В.О., 39, лит. В
#
#                                    historical_category  \
# 0               выявленный объект культурного наследия
# 1               выявленный объект культурного наследия
# 2               выявленный объект культурного наследия
# 3    объект культурного наследия федерального значения
# 4    объект культурного наследия регионального знач...
# ..                                                 ...
# 777  объект культурного наследия регионального знач...
# 778  объект культурного наследия регионального знач...
# 779  объект культурного наследия регионального знач...
# 780  объект культурного наследия регионального знач...
# 781  объект культурного наследия регионального знач...
#
#                                          normative_act object_type  \
# 0         Приказ председателя КГИОП № 15 от 20.02.2001    Памятник
# 1         Приказ председателя КГИОП № 15 от 20.02.2001    Памятник
# 2         Приказ председателя КГИОП № 15 от 20.02.2001    Памятник
# 3    Постановление Правительства РФ № 527 от 10.07....    Памятник
# 4             Распоряжение КГИОП № 139-р от 23.04.2021    Памятник
# ..                                                 ...         ...
# 777           Распоряжение КГИОП от 22.03.2016 № 10-92    Памятник
# 778           Распоряжение КГИОП от 22.03.2016 № 10-92    Ансамбль
# 779           Распоряжение КГИОП от 01.07.2019 № 365-р    Памятник
# 780           Распоряжение КГИОП от 05.08.2019 № 437-р    Памятник
# 781           Распоряжение КГИОП от 05.08.2019 № 437-р    Памятник
#
#                             geometry
# 0    POINT (3370436.885 8386572.161)
# 1    POINT (3371907.580 8386491.569)
# 2    POINT (3372020.006 8386392.023)
# 3    POINT (3372009.644 8386417.444)
# 4    POINT (3372026.660 8386473.431)
# ..                               ...
# 777  POINT (3369220.867 8386925.034)
# 778  POINT (3369290.775 8386927.924)
# 779  POINT (3372240.630 8387172.627)
# 780  POINT (3370714.885 8387675.618)
# 781  POINT (3370751.287 8387603.157)
#
# [782 rows x 9 columns]

# %% [markdown]
# Оставим только столбцы object_name, object_location, object_type и geometry

# %%
# DONE todo оставить только столбцы object_name, object_location, object_type
#gdf_kgiop_objects = gdf_kgiop_objects[['object_name', 'object_location', 'object_type']]
gdf_kgiop_objects = gdf_kgiop_objects.loc[:, ('object_name', 'object_location', 'object_type', 'geometry')]
gdf_kgiop_objects
# Out:
#                                            object_name  \
# 0                                    Дом А.Р. Гешвенда
# 1                                              Флигель
# 2                   Дом Г.И. Головкина (А.Н. Чичагова)
# 3                    Дом Леонтьева М.И. (Шуберта Ф.Ф.)
# 4                         Дом А. Сверчкова (Кушелевой)
# ..                                                 ...
# 777                                             Ограда
# 778                                                Сад
# 779  Главное здание Государственного оптического ин...
# 780                                      Жилой флигель
# 781                                      Жилой флигель
#
#                          object_location object_type  \
# 0                     9-я линия В.О., 32    Памятник
# 1                         Репина ул., 17    Памятник
# 2      1-я линия В.О., 10; Репина ул., 9    Памятник
# 3                     1-я линия В.О., 12    Памятник
# 4             1-я линия В.О., 14, лит. А    Памятник
# ..                                   ...         ...
# 777               14-я линия В.О., 57-61    Памятник
# 778               14-я линия В.О., 57-61    Ансамбль
# 779  Кадетская линия, 5, корп. 2, лит. В    Памятник
# 780           4-я линия В.О., 39, лит. Б    Памятник
# 781           4-я линия В.О., 39, лит. В    Памятник
#
#                             geometry
# 0    POINT (3370436.885 8386572.161)
# 1    POINT (3371907.580 8386491.569)
# 2    POINT (3372020.006 8386392.023)
# 3    POINT (3372009.644 8386417.444)
# 4    POINT (3372026.660 8386473.431)
# ..                               ...
# 777  POINT (3369220.867 8386925.034)
# 778  POINT (3369290.775 8386927.924)
# 779  POINT (3372240.630 8387172.627)
# 780  POINT (3370714.885 8387675.618)
# 781  POINT (3370751.287 8387603.157)
#
# [782 rows x 4 columns]

# %% [markdown]
# Переименуем столбцы *object_name*, *object_location*, *object_type* в русские названия

# %%
# DONE todo переименовать столбцы object_name, object_location, object_type в русские названия
rename_columns = {
    "object_name": "Название объекта",
    "object_location": "Местоположение объекта",
    "object_type": "Тип объекта"
}
gdf_kgiop_objects.rename(columns=rename_columns, inplace=True)
gdf_kgiop_objects
# Out:
#                                       Название объекта  \
# 0                                    Дом А.Р. Гешвенда
# 1                                              Флигель
# 2                   Дом Г.И. Головкина (А.Н. Чичагова)
# 3                    Дом Леонтьева М.И. (Шуберта Ф.Ф.)
# 4                         Дом А. Сверчкова (Кушелевой)
# ..                                                 ...
# 777                                             Ограда
# 778                                                Сад
# 779  Главное здание Государственного оптического ин...
# 780                                      Жилой флигель
# 781                                      Жилой флигель
#
#                   Местоположение объекта Тип объекта  \
# 0                     9-я линия В.О., 32    Памятник
# 1                         Репина ул., 17    Памятник
# 2      1-я линия В.О., 10; Репина ул., 9    Памятник
# 3                     1-я линия В.О., 12    Памятник
# 4             1-я линия В.О., 14, лит. А    Памятник
# ..                                   ...         ...
# 777               14-я линия В.О., 57-61    Памятник
# 778               14-я линия В.О., 57-61    Ансамбль
# 779  Кадетская линия, 5, корп. 2, лит. В    Памятник
# 780           4-я линия В.О., 39, лит. Б    Памятник
# 781           4-я линия В.О., 39, лит. В    Памятник
#
#                             geometry
# 0    POINT (3370436.885 8386572.161)
# 1    POINT (3371907.580 8386491.569)
# 2    POINT (3372020.006 8386392.023)
# 3    POINT (3372009.644 8386417.444)
# 4    POINT (3372026.660 8386473.431)
# ..                               ...
# 777  POINT (3369220.867 8386925.034)
# 778  POINT (3369290.775 8386927.924)
# 779  POINT (3372240.630 8387172.627)
# 780  POINT (3370714.885 8387675.618)
# 781  POINT (3370751.287 8387603.157)
#
# [782 rows x 4 columns]

# %% [markdown]
# Отобразим на карте объекты культурного наследия Василеостровского района

# %%
gdf_kgiop_objects.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_960f401583b79b977d9f3d9f085ef081 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_960f401583b79b977d9f3d9f085ef081&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_960f401583b79b977d9f3d9f085ef081 = L.map(
#                 &quot;map_960f401583b79b977d9f3d9f085ef081&quot;,
#                 {
#                     center: [59.93804486965, 30.265026144749996],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_960f401583b79b977d9f3d9f085ef081);
#
#
#
#
#
#             var tile_layer_e0bc7af8483f9b2e55c20fdc2e802c80 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_960f401583b79b977d9f3d9f085ef081);
#
#
#             map_960f401583b79b977d9f3d9f085ef081.fitBounds(
#                 [[59.92093432170001, 30.222024289500002], [59.9551554176, 30.308027999999993]],
#                 {}
#             );
#
#
#         function geo_json_112a3ecba1bc8c8c9d67177c875d99f0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_112a3ecba1bc8c8c9d67177c875d99f0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_112a3ecba1bc8c8c9d67177c875d99f0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_112a3ecba1bc8c8c9d67177c875d99f0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_112a3ecba1bc8c8c9d67177c875d99f0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_112a3ecba1bc8c8c9d67177c875d99f0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_112a3ecba1bc8c8c9d67177c875d99f0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_112a3ecba1bc8c8c9d67177c875d99f0 = L.geoJson(null, {
#                 onEachFeature: geo_json_112a3ecba1bc8c8c9d67177c875d99f0_onEachFeature,
#
#                 style: geo_json_112a3ecba1bc8c8c9d67177c875d99f0_styler,
#                 pointToLayer: geo_json_112a3ecba1bc8c8c9d67177c875d99f0_pointToLayer
#         });
#
#         function geo_json_112a3ecba1bc8c8c9d67177c875d99f0_add (data) {
#             geo_json_112a3ecba1bc8c8c9d67177c875d99f0
#                 .addData(data)
#                 .addTo(map_960f401583b79b977d9f3d9f085ef081);
#         }
#             geo_json_112a3ecba1bc8c8c9d67177c875d99f0_add({&quot;bbox&quot;: [30.222024289500002, 59.92093432170001, 30.308027999999993, 59.9551554176], &quot;features&quot;: [{&quot;bbox&quot;: [30.277149679099992, 59.94081224709999, 30.277149679099992, 59.94081224709999], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.277149679099992, 59.94081224709999], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;\u041c\u0435\u0441\u0442\u043e\u043f\u043e\u043b\u043e\u0436\u0435\u043d\u0438\u0435 \u043e\u0431\u044a\u0435\u043a\u0442\u0430&quot;: &quot;9-\u044f \u043b\u0438\u043d\u0438\u044f \u0412.\u041e., 32&quot;, &quot;\u041d\u0430\u0437\u

# %% [markdown]
# Используем ранее заданный буфер в 100 метров для подсчета кол-ва объектов культурного наследия, попадающих в буфер улицы

# %%
def get_contains_kgiop_objects(street) -> int:
    """ Функция для подсчета количества объектов культурного наследия попадающих в буффер улицы"""
    return sum(gdf_kgiop_objects["geometry"].within(street.buffer(STREET_BUFFER)))


gdf_streets["contains_kgiop_objects"] = gdf_streets["geometry"].apply(get_contains_kgiop_objects)
gdf_streets.nlargest(5, "contains_kgiop_objects")
# Out:
#                                                                 geometry  \
# Название улицы
# 4-5-я линии В.О.       MULTILINESTRING ((3370879.560 8387254.041, 337...
# 1-я линия В.О.         MULTILINESTRING ((3371228.480 8388213.098, 337...
# 8-я линия В.О.         MULTILINESTRING ((3371178.720 8385438.273, 337...
# 9-я линия В.О.         MULTILINESTRING ((3370822.954 8386044.168, 337...
# Средний проспект В.О.  MULTILINESTRING ((3366331.992 8384554.141, 336...
#
#                        contains_kgiop_objects
# Название улицы
# 4-5-я линии В.О.                           49
# 1-я линия В.О.                             42
# 8-я линия В.О.                             38
# 9-я линия В.О.                             37
# Средний проспект В.О.                      37

# %% [markdown]
# Визуализируем полученные выше данные

# %%
gdf_streets.explore("contains_kgiop_objects", tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d46f6b321643766ce5d5115dab0a9606 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d46f6b321643766ce5d5115dab0a9606&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d46f6b321643766ce5d5115dab0a9606 = L.map(
#                 &quot;map_d46f6b321643766ce5d5115dab0a9606&quot;,
#                 {
#                     center: [59.94541845, 30.251080950000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d46f6b321643766ce5d5115dab0a9606);
#
#
#
#
#
#             var tile_layer_121d9506db9c7ee4969a5683de24435f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d46f6b321643766ce5d5115dab0a9606);
#
#
#             map_d46f6b321643766ce5d5115dab0a9606.fitBounds(
#                 [[59.921740099999994, 30.192633900000004], [59.9690968, 30.309527999999997]],
#                 {}
#             );
#
#
#         function geo_json_1eefd17e4e0f79ffc2963e1ff6767c88_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#a0da39&quot;, &quot;fillColor&quot;: &quot;#a0da39&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#218e8d&quot;, &quot;fillColor&quot;: &quot;#218e8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#25838e&quot;, &quot;fillColor&quot;: &quot;#25838e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#277f8e&quot;, &quot;fillColor&quot;: &quot;#277f8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;28&quot;: case &quot;52&quot;: case &quot;61&quot;: case &quot;83&quot;: case &quot;90&quot;:
#                     return {&quot;color&quot;: &quot;#482576&quot;, &quot;fillColor&quot;: &quot;#482576&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;40&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;102&quot;:
#                     return {&quot;color&quot;: &quot;#481d6f&quot;, &quot;fillColor&quot;: &quot;#481d6f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#3c508b&quot;, &quot;fillColor&quot;: &quot;#3c508b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;8&quot;: case &quot;14&quot;: case &quot;41&quot;: case &quot;49&quot;: case &quot;76&quot;: case &quot;82&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;110&quot;: case &quot;115&quot;:
#                     return {&quot;color&quot;: &quot;#471063&quot;, &quot;fillColor&quot;: &quot;#471063&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#23898e&quot;, &quot;fillColor&quot;: &quot;#23898e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;58&quot;:
#                     return {&quot;color&quot;: &quot;#404588&quot;, &quot;fillColor&quot;: &quot;#404588&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;45&quot;:
#                     return {&quot;color&quot;: &quot;#3e4a89&quot;, &quot;fillColor&quot;: &quot;#3e4a89&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;38&quot;: case &quot;88&quot;:
#                     return {&quot;color&quot;: &quot;#423f85&quot;, &quot;fillColor&quot;: &quot;#423f85&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quot;:
#                     re

# %% [markdown]
# Посчитаем плотность расположения объектов культурного наследия на улице

# %%
gdf_streets["density"] = gdf_streets["contains_kgiop_objects"] / gdf_streets.length

select_columns = []
gdf_streets.nlargest(5, "density")
# Out:
#                                                                  geometry  \
# Название улицы
# Магдалинский переулок   LINESTRING (3371179.834 8388009.593, 3371170.3...
# Волжский переулок       MULTILINESTRING ((3371127.736 8386504.434, 337...
# Академический переулок  MULTILINESTRING ((3371097.813 8385596.753, 337...
# Днепровский переулок    LINESTRING (3371234.024 8385674.972, 3371231.3...
# 7-я линия В.О.          LINESTRING (3370595.996 8387058.387, 3370622.3...
#
#                         contains_kgiop_objects   density
# Название улицы
# Магдалинский переулок                        5  0.066585
# Волжский переулок                           14  0.022229
# Академический переулок                      14  0.021333
# Днепровский переулок                        11  0.021283
# 7-я линия В.О.                              19  0.019892

# %% [markdown]
# Переименуем столбцы *contains_kgiop_objects*	и *density* в русские названия

# %%
# DONE todo переименовать столбцы contains_kgiop_objects	и density в русские названия
rename_columns = {
    "contains_kgiop_objects": "Кол-во объектов культурного наследия",
    "density": "Плотность объектов культурного наследия на улице",
}
gdf_streets.rename(columns=rename_columns, inplace=True)
gdf_streets
# Out:
#                                                              geometry  \
# Название улицы
# 1-я линия В.О.      MULTILINESTRING ((3371228.480 8388213.098, 337...
# 10-11-я линии В.О.  MULTILINESTRING ((3369235.249 8388117.669, 336...
# 12-13-я линии В.О.  MULTILINESTRING ((3370596.664 8385143.832, 337...
# 14-15-я линии В.О.  LINESTRING (3369473.640 8386432.496, 3369476.8...
# 14-я линия В.О.     LINESTRING (3369473.640 8386432.496, 3369470.2...
# ...                                                               ...
# улица Нахимова      MULTILINESTRING ((3364793.702 8386752.080, 336...
# улица Одоевского    MULTILINESTRING ((3368096.740 8388961.412, 336...
# улица Репина        MULTILINESTRING ((3371298.233 8387498.912, 337...
# улица Челюскина     LINESTRING (3361436.751 8386728.833, 3361263.5...
# улица Шевченко      MULTILINESTRING ((3367088.419 8383856.438, 336...
#
#                     Кол-во объектов культурного наследия  \
# Название улицы
# 1-я линия В.О.                                        42
# 10-11-я линии В.О.                                    24
# 12-13-я линии В.О.                                    22
# 14-15-я линии В.О.                                    21
# 14-я линия В.О.                                        5
# ...                                                  ...
# улица Нахимова                                         0
# улица Одоевского                                       0
# улица Репина                                          31
# улица Челюскина                                        0
# улица Шевченко                                         0
#
#                     Плотность объектов культурного наследия на улице
# Название улицы
# 1-я линия В.О.                                              0.016447
# 10-11-я линии В.О.                                          0.007373
# 12-13-я линии В.О.                                          0.006398
# 14-15-я линии В.О.                                          0.012094
# 14-я линия В.О.                                             0.002621
# ...                                                              ...
# улица Нахимова                                              0.000000
# улица Одоевского                                            0.000000
# улица Репина                                                0.019799
# улица Челюскина                                             0.000000
# улица Шевченко                                              0.000000
#
# [122 rows x 3 columns]

# %% [markdown]
# Визуализируем на карте распределение объектов культурного наследия по улицам района

# %%
m = gdf_streets.explore("Кол-во объектов культурного наследия", tiles=TILES)
m = territory.explore(m=m, style_kwds={"fill": False, "weight": 5})

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0775b9517382ba673fc3a60d8cd34965 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0775b9517382ba673fc3a60d8cd34965&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0775b9517382ba673fc3a60d8cd34965 = L.map(
#                 &quot;map_0775b9517382ba673fc3a60d8cd34965&quot;,
#                 {
#                     center: [59.94541845, 30.251080950000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0775b9517382ba673fc3a60d8cd34965);
#
#
#
#
#
#             var tile_layer_316b815390af0a8564c08cd9888c6972 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0775b9517382ba673fc3a60d8cd34965);
#
#
#             map_0775b9517382ba673fc3a60d8cd34965.fitBounds(
#                 [[59.921740099999994, 30.192633900000004], [59.9690968, 30.309527999999997]],
#                 {}
#             );
#
#
#         function geo_json_342d6ed49da30ad4780393951181622e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#a0da39&quot;, &quot;fillColor&quot;: &quot;#a0da39&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#218e8d&quot;, &quot;fillColor&quot;: &quot;#218e8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#25838e&quot;, &quot;fillColor&quot;: &quot;#25838e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#277f8e&quot;, &quot;fillColor&quot;: &quot;#277f8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;28&quot;: case &quot;52&quot;: case &quot;61&quot;: case &quot;83&quot;: case &quot;90&quot;:
#                     return {&quot;color&quot;: &quot;#482576&quot;, &quot;fillColor&quot;: &quot;#482576&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;40&quot;: case &quot;59&quot;: case &quot;63&quot;: case &quot;102&quot;:
#                     return {&quot;color&quot;: &quot;#481d6f&quot;, &quot;fillColor&quot;: &quot;#481d6f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#3c508b&quot;, &quot;fillColor&quot;: &quot;#3c508b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;8&quot;: case &quot;14&quot;: case &quot;41&quot;: case &quot;49&quot;: case &quot;76&quot;: case &quot;82&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;110&quot;: case &quot;115&quot;:
#                     return {&quot;color&quot;: &quot;#471063&quot;, &quot;fillColor&quot;: &quot;#471063&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#23898e&quot;, &quot;fillColor&quot;: &quot;#23898e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;58&quot;:
#                     return {&quot;color&quot;: &quot;#404588&quot;, &quot;fillColor&quot;: &quot;#404588&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&

# %% [markdown]
# Сохраним датафрейм gdf_streets в файл streets_with_contains_kgiop.geojson в формате geojson

# %%
# todo сохранить датафрейм gdf_streets в файл streets_with_contains_kgiop.geojson в формате geojson
gdf_streets.to_file('streets_with_contains_kgiop.geojson', driver='GeoJSON')
